# %%
import pandas as pd
from helpers.word2vec import visualize_most_frequent, visualize_words, full_train_model, get_vector_representations, distance_sum_metric, p_at_k_metric
from gensim.models import Word2Vec

# %% [markdown]
# # Interleaved

# %% [markdown]
# ## Trénování modelu

# %%
interleaved = pd.read_csv("corpus/eurlex/interleaved.csv")
interleaved.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# %%time
window = 5
vector_size = 100
model_type = 'cbow'

interleaved_model = Word2Vec(window=window, min_count=3, negative=1, workers=4, sg=1 if 'sg' else 0, vector_size=vector_size)
full_train_model(interleaved_model, interleaved)
print("trained_models/eurlex_simple_joined_{:s}_{:d}x{:d}".format(model_type, window, vector_size))
interleaved_model.save("trained_models/eurlex_simple_joined_{:s}_{:d}x{:d}".format(model_type, window, vector_size))

# %% [markdown]
# # Simple joined

# %% [markdown]
# ## Trénování modelu

# %%
simple_joined = pd.read_csv('corpus/eurlex/simple_joined.csv')
simple_joined.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# %%time
window = 75
vector_size = 50
simple_joined_model = Word2Vec(window=window, min_count=1, negative=1, workers=4, sg=1, vector_size=vector_size)
full_train_model(simple_joined_model, simple_joined)
simple_joined_model.save("trained_models/eurlex_simple_joined_sg_{:d}x{:d}".format(window, vector_size))
# Out:
# Iteration 0/4
# Iteration 1/4
# Iteration 2/4
# Iteration 3/4
# CPU times: user 25min 16s, sys: 2.45 s, total: 25min 18s
# Wall time: 8min 13s

# %% [markdown]
# # Vizualizace výsledků pomocí PCA a t-SNE

# %%
interleaved_model = Word2Vec.load('trained_models/eurlex_interleaved_cbow_5x100')

# %%
get_vector_representations(interleaved_model).to_csv('corpus/eurlex/vector_representations.csv')

# %%
en_words = ['access', 'authoris', 'capit', 'committe', 'consum', 'content', 'deadlin', 'document', 'expenditur', 'full', 'geograph', 'group', 'growth', 'hear', 'instrument', 'investig', 'label', 'list', 'loan', 'network', 'opinion', 'partnership', 'pension', 'price', 'sale', 'secret', 'solut', 'trade', 'type', 'wast']
cz_words = ['přístup', 'povolen', 'kapitál', 'výbor', 'spotřebitel', 'obsah', 'lhůt', 'dokument', 'výdaj', 'pln', 'zeměpisn', 'skup', 'růst', 'slyšen', 'nástroj', 'šetřen', 'označen', 'seznam', 'úvěr', 'síť', 'stanovisk', 'partnerst', 'důchod', 'cen', 'prodej', 'tajemstv', 'řešen', 'obchod', 'typ', 'odpad']

# %%
en_freqs = pd.read_csv('corpus/eurlex/en_freqs.csv')
cz_freqs = pd.read_csv('corpus/eurlex/cz_freqs.csv')

# %%
visualize_most_frequent(interleaved_model, en_freqs, cz_freqs, perplexity=30)
# Out:
# <div>                            <div id="aad7d896-b257-4654-8ca4-0c7e0d35e4ec" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aad7d896-b257-4654-8ca4-0c7e0d35e4ec")) {                    Plotly.newPlot(                        "aad7d896-b257-4654-8ca4-0c7e0d35e4ec",                        [{"hovertemplate":"language=cz<br>t-SNE axe 1=%{x}<br>t-SNE axe 2=%{y}<br>token=%{text}<extra></extra>","legendgroup":"cz","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"cz","showlegend":true,"text":["the","of","and","in","eu","for","is","european","that","member","with","commission","as","are","be","this","has","it","which","articl","council","not","de","hav","union","from","law","will","right","at","an","use","its","provid","support","or","sta","one","been","includ","public","may","new","part","would","human","eur","their","programm","als","market","inform","order","agreement","report","komis","la","peopl","project","all","ensur","was","concern","number","could","dne","na\u0159\u00edzen","must","rights","person","action","possibl","such","region","can","year","di","thes","issu","framework","evropsk","sector","fund","social","question","air","well","subject","europ","particular","work","rozhodnut","respect","parliament","countr","court","regard","million","level","podnik","dat","authorit","other","stat","whether","ec","access","does","under","result","need","view","\u010dl","set","group","recent","odst","taken","process","plan","rad","risk","health","greek","increas","en","national","period","un","account","full","st\u00e1t","e","aid","given","directiv","therefor","continu","legal","mor","osob","procedur","polic","first","no","cost","measu","program","government","int","including","wer","ther","uni","information","research","international","impact","any","privat","awar","what","wast","current","som","high","children","opat\u0159en","who","internet","transport","bank","uveden","form","if","r\u00e1mk","der","between","per","term","out","fact","being","common","against","context","development","two","\u0159\u00edzen","reform","pr\u00e1v","but","through","kter","italian","protection","without","spole\u010dnost","onl","oblast","\u010dlensk","local","point","situation","however","total","should","up","hospod\u00e1\u0159sk","control","regulation","citizens","among","die","thos","intend","stran","natur","l","spanish","years","p\u0159\u00edpad","due","syst","according","pr\u00e1vn","over","energi","es","strategi","light","civil","wher","je\u017e","present","water","z\u00e1klad","spojen","end","list","economic","cas","\u00fadaj","second","ochran","legislation","ozn\u00e1men","dell","securit","strateg","march","ustanoven","sink","man","del","about","political","bod","than","decision","us","polik","trh","af","energ","when","projects","mad","stanoven","compan","them","specific","b","zn\u011bn","il","had","v\u00fd\u0161","cooperation","how","financial","areas","rok","conditions","tax","so","soulad","progress","le","ca","spain","uk","activit","futur","further","implementation","necessar","women","sa","trad","after","turke","da","skup","og","servi","p\u00edsm","now","http","most","subjekt","fre","t\u00fdkaj\u00edc","car","sm\u011brnik","used","alread","tim","n\u00e1vrh","adopted","tre","following","plak","billion","spole\u010dn","zve\u0159ejn\u011bn","far","org\u00e1n","ru","m\u011bl","t\u011bcht","zem","stud","che","c\u00edl","basis","during","certa","standard","centr","products","april","dispozik","v\u011bst","\u00fa\u0159","podpor","communit","van","environmental","met","relevant","assistank","currentl","z\u00fa\u010dastn\u011bn","provisions","jednac","german","\u017e\u00e1dost","p\u00e5","dob","sam","druh","el","food","consider","hodnot","funding","c","pot","w","li","both","er","negotiati ...

# %%
visualize_words(interleaved_model, en_words, cz_words, perplexity=15)
# Out:
# <div>                            <div id="27501a6c-d3ff-4cfa-a112-21eb3584b633" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27501a6c-d3ff-4cfa-a112-21eb3584b633")) {                    Plotly.newPlot(                        "27501a6c-d3ff-4cfa-a112-21eb3584b633",                        [{"hovertemplate":"language=en<br>t-SNE axe 1=%{x}<br>t-SNE axe 2=%{y}<br>token=%{text}<extra></extra>","legendgroup":"en","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"en","orientation":"v","showlegend":true,"text":["access","group","full","wast","trade","investig","network","growth","list","consum","document","opinion","committe","sale","instrument","authoris","partnership","price","loan","capit","pension","solut","secret","content","type","hear","label","expenditur","deadlin","geograph"],"x":[101.46670532226562,-99.92986297607422,136.87811279296875,-48.271873474121094,-20.163169860839844,43.788116455078125,-71.55918884277344,0.050543513149023056,90.27336883544922,47.409664154052734,-52.258426666259766,-85.74614715576172,-79.83367919921875,30.228322982788086,59.554386138916016,118.60344696044922,-50.221839904785156,-0.9600154161453247,76.01820373535156,25.753780364990234,-52.220645904541016,7.468845844268799,-7.184194564819336,-34.08201599121094,-98.80997467041016,25.339092254638672,60.16349411010742,-18.168365478515625,69.79279327392578,67.19184875488281],"xaxis":"x","y":[52.22235107421875,-103.7847671508789,-27.89380645751953,113.405029296875,32.96269607543945,-43.20656967163086,59.39260482788086,9.853302955627441,-47.11619567871094,62.591697692871094,-55.519805908203125,-46.001895904541016,-74.5347671508789,-7.12209415435791,111.52069091796875,25.496536254882812,21.512765884399414,75.66427612304688,87.4952163696289,29.317739486694336,-3.7628836631774902,111.40567779541016,-67.8505630493164,-100.09700012207031,6.346198558807373,-90.08698272705078,-14.052838325500488,-34.20036315917969,-88.89478302001953,18.254838943481445],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"language=cz<br>t-SNE axe 1=%{x}<br>t-SNE axe 2=%{y}<br>token=%{text}<extra></extra>","legendgroup":"cz","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers+text","name":"cz","orientation":"v","showlegend":true,"text":["skup","p\u0159\u00edstup","cen","\u0161et\u0159en","dokument","seznam","n\u00e1stroj","spot\u0159ebitel","tajemstv","\u00fav\u011br","povolen","r\u016fst","prodej","kapit\u00e1l","stanovisk","pln","ozna\u010den","lh\u016ft","v\u00fddaj","obchod","typ","v\u00fdbor","sly\u0161en","\u0159e\u0161en","zem\u011bpisn","obsah","d\u016fchod","s\u00ed\u0165","odpad","partnerst"],"x":[-106.412109375,88.72675323486328,10.194786071777344,31.25454330444336,-51.30693054199219,85.44696044921875,46.923404693603516,35.584964752197266,3.7585642337799072,66.09703826904297,105.97776794433594,-7.627490043640137,30.609161376953125,34.99766159057617,-94.07101440429688,134.68199157714844,74.48689270019531,57.5413932800293,-9.844746589660645,-11.605395317077637,-107.74332427978516,-94.32412719726562,31.49285125732422,21.058948516845703,60.818267822265625,-22.17508888244629,-41.78089141845703,-75.8843994140625,-44.99225997924805,-47.57093048095703],"xaxis":"x","y":[-92.38365936279297,50.72687911987305,70.29529571533203,-43.105751037597656,-68.33209991455078,-35.81220626831055,112.71879577636719,69.1291275024414,-63.39081954956055,79.67694091796875,24.384449005126953,0.5718073844909668,-20.423542022705078,37.85979080200195,-56.6285514831543,-15.455646514892578,-4.834554672241211,-89.77091979980469,-24.844066619873047,42.10194396972656,-2.3950860500335693,-73.57495880126953,-79.60516357421875,114.66554260253906,6.986239910125732,-98.74413299560547,-10.002571105957031,47.779750823974 ...

# %% [markdown]
# # Evaluace úspěšnosti modelu

# %%
models = ['cbow']
for model_type in models:
    for vector_size in range(200, 300, 100):
        for window in range(100, 175, 25):
            model = Word2Vec.load("trained_models/eurlex_simple_joined_{:s}_{:d}x{:d}".format(model_type, window, vector_size))
            print("-----Vector Size: {:d}, Context Window: {:d}, Model Type: {:s}-----".format(vector_size, window, model_type))
            distance_sum = distance_sum_metric(model, en_words, cz_words, en_freqs)
            print("Distance sum: {:f}".format(distance_sum))
            p_at_k = p_at_k_metric(model, en_words, cz_words, en_freqs, k=10)
            print("P@10: {:f}".format(p_at_k))
# Out:
# -----Vector Size: 200, Context Window: 100, Model Type: cbow-----
# P@10: 0.833333
# -----Vector Size: 200, Context Window: 125, Model Type: cbow-----
# P@10: 0.800000
# -----Vector Size: 200, Context Window: 150, Model Type: cbow-----
# P@10: 0.900000

# %%
vector_size = 200
window = 8
model_type = 'cbow'
model = Word2Vec.load("trained_models/eurlex_interleaved_{:s}_{:d}x{:d}".format(model_type, window, vector_size))
print("-----Vector Size: {:d}, Context Window: {:d}, Model Type: {:s}-----".format(vector_size, window, model_type))
distance_sum = distance_sum_metric(model, en_words, cz_words, en_freqs)
print("Distance sum: {:f}".format(distance_sum))
p_at_k = p_at_k_metric(model, en_words, cz_words, en_freqs, k=10)
print("P@10: {:f}".format(p_at_k))
# Out:
# -----Vector Size: 200, Context Window: 8, Model Type: cbow-----
# P@10: 0.800000

# %%
from helpers.word2vec import get_single_representation, cosine_distance
def all_tests(model, en_words, cz_words, en_freqs):
    distance_sum = 0
    success_5 = 0
    success_10 = 0
    df = get_vector_representations(model)
    all_en_words = en_freqs['Unnamed: 0'].values.tolist()
    en_representations = df.loc[df['token'].isin(all_en_words)]
    for i in range(len(en_words)):
        cz_repr = get_single_representation(model, cz_words[i])
        en_repr = get_single_representation(model, en_words[i])
        distances = en_representations.apply(lambda x: cosine_distance(x[list(range(1, model.vector_size + 1))].tolist(), cz_repr), axis=1)
        distances.rename('distances', inplace=True)
        largest_dist = distances.max()
        distance_sum += cosine_distance(en_repr, cz_repr) / largest_dist

        merged = pd.concat([distances, en_representations], axis=1)
        neighbors_5 = merged.nsmallest(5, 'distances')['token'].tolist()
        neighbors_10 = merged.nsmallest(10, 'distances')['token'].tolist()
        if en_words[i] in neighbors_5:
            success_5 += 1
        if en_words[i] in neighbors_10:
            success_10 += 1
    print("P@5:", success_5 / len(en_words))
    print("P@10:", success_10 / len(en_words))
    print("distance_sum:", distance_sum)

# %%
models = ['sg']
vector_size = 50
for model_type in models:
    for window in range(50, 175, 25):
        model = Word2Vec.load("trained_models/eurlex_simple_joined_{:s}_{:d}x{:d}".format(model_type, window, vector_size))
        print("-----Vector Size: {:d}, Context Window: {:d}, Model Type: {:s}-----".format(vector_size, window, model_type))
        all_tests(model, en_words, cz_words, en_freqs)
# Out:
# -----Vector Size: 50, Context Window: 50, Model Type: sg-----
# P@5: 0.26666666666666666
# P@10: 0.36666666666666664
# distance_sum: 4.772666817319418
# -----Vector Size: 50, Context Window: 75, Model Type: sg-----
# P@5: 0.4
# P@10: 0.43333333333333335
# distance_sum: 5.331978549992691
# -----Vector Size: 50, Context Window: 100, Model Type: sg-----
# P@5: 0.36666666666666664
# P@10: 0.43333333333333335
# distance_sum: 5.264594803225473
# -----Vector Size: 50, Context Window: 125, Model Type: sg-----
# P@5: 0.3333333333333333
# P@10: 0.36666666666666664
# distance_sum: 4.998102937632998
# -----Vector Size: 50, Context Window: 150, Model Type: sg-----
# P@5: 0.3333333333333333
# P@10: 0.36666666666666664
# distance_sum: 5.443800120999057
